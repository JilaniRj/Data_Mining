# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("annual_data.csv")

# %%
df
# Out:
#        Period                         Inst_sector  Inst_sector_code  \
# 0     2013.06  Non-corporate business enterprises               121
# 1     2013.06  Non-corporate business enterprises               121
# 2     2013.06  Non-corporate business enterprises               121
# 3     2013.06  Non-corporate business enterprises               121
# 4     2013.06  Non-corporate business enterprises               121
# ...       ...                                 ...               ...
# 7291     2015                   Total all sectors               900
# 7292     2015                   Total all sectors               900
# 7293     2015                   Total all sectors               900
# 7294     2015                   Total all sectors               900
# 7295     2015                   Total all sectors               900
#
#                                              Descriptor SNA08TRANS  \
# 0                          Closing balance total assets    LE00000
# 1     Financial assets Closing balance Total financi...    LE00000
# 2     Financial assets Closing balance monetary gold...    LE00000
# 3     Financial assets Closing balance currency and ...    LE00000
# 4      Financial assets Closing balance debt securities    LE00000
# ...                                                 ...        ...
# 7291  Capital Account Closing balances Total non-fin...    LE00000
# 7292  Capital Account Closing balances Produced non-...    LE00000
# 7293  Capital Account Closing balances Non-produced ...    LE00000
# 7294                          Closing balance net worth    LE00000
# 7295    Closing balance total liabilities and net worth    LE00000
#
#      Asset_liability_code
# 0                 A000000
# 1                 AFA0000
# 2                 AFA0100
# 3                 AFA0200
# 4                 AFA0300
# ...                   ...
# 7291              AN00000
# 7292              AN10000
# 7293              AN20000
# 7294              B900000
# 7295              L000000
#
# [7296 rows x 6 columns]

# %%
df=df.drop('SNA08TRANS',axis=1)

# %%
df=df.drop('Descriptor',axis=1)

# %%
df=df.drop('Inst_sector',axis=1)

# %%
df
# Out:
#        Period  Inst_sector_code Asset_liability_code
# 0     2013.06               121              A000000
# 1     2013.06               121              AFA0000
# 2     2013.06               121              AFA0100
# 3     2013.06               121              AFA0200
# 4     2013.06               121              AFA0300
# ...       ...               ...                  ...
# 7291     2015               900              AN00000
# 7292     2015               900              AN10000
# 7293     2015               900              AN20000
# 7294     2015               900              B900000
# 7295     2015               900              L000000
#
# [7296 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7296 entries, 0 to 7295
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Period                7296 non-null   object
#  1   Inst_sector_code      7296 non-null   int64
#  2   Asset_liability_code  7296 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 171.1+ KB

# %%
df['Period']=pd.to_datetime(df['Period'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10440\2930140844.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Period']=pd.to_datetime(df['Period'])

# %%
df
# Out:
#          Period  Inst_sector_code Asset_liability_code
# 0    2013-06-01               121              A000000
# 1    2013-06-01               121              AFA0000
# 2    2013-06-01               121              AFA0100
# 3    2013-06-01               121              AFA0200
# 4    2013-06-01               121              AFA0300
# ...         ...               ...                  ...
# 7291 2015-01-01               900              AN00000
# 7292 2015-01-01               900              AN10000
# 7293 2015-01-01               900              AN20000
# 7294 2015-01-01               900              B900000
# 7295 2015-01-01               900              L000000
#
# [7296 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Period']=le.fit_transform(df['Period'])
df['Asset_liability_code']=le.fit_transform(df['Asset_liability_code'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7296 entries, 0 to 7295
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Period                7296 non-null   int64
#  1   Inst_sector_code      7296 non-null   int64
#  2   Asset_liability_code  7296 non-null   int32
# dtypes: int32(1), int64(2)
# memory usage: 142.6 KB

# %%
df
# Out:
#       Period  Inst_sector_code  Asset_liability_code
# 0          0               121                     0
# 1          0               121                     1
# 2          0               121                     2
# 3          0               121                     3
# 4          0               121                     4
# ...      ...               ...                   ...
# 7291       3               900                    19
# 7292       3               900                    20
# 7293       3               900                    21
# 7294       3               900                    22
# 7295       3               900                    23
#
# [7296 rows x 3 columns]

# %%
plt.hist(df['Inst_sector_code'])
# Out:
# (array([ 768., 3072., 1536.,  384.,    0.,  384.,  384.,    0.,  384.,
#          384.]),
#  array([121. , 198.9, 276.8, 354.7, 432.6, 510.5, 588.4, 666.3, 744.2,
#         822.1, 900. ]),
#  <BarContainer object of 10 artists>)

# %%
x=df['Period']
y=df['Asset_liability_code']
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 7296 artists>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
get_ipython().system('pip install prophet')
# Out:
# Collecting prophet
#   Obtaining dependency information for prophet from https://files.pythonhosted.org/packages/24/2b/834e9a347f2f0161e32a3c6125b8a1ebdf6ac33199a0ed3a0bdf1f0c296f/prophet-1.1.5-py3-none-win_amd64.whl.metadata
#   Downloading prophet-1.1.5-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Obtaining dependency information for cmdstanpy>=1.0.4 from https://files.pythonhosted.org/packages/e8/e2/2ddc273e726680a3c816f9a05c6726d57d61820fa7ab4753ed282d0a8bbe/cmdstanpy-1.2.0-py3-none-any.whl.metadata
#   Downloading cmdstanpy-1.2.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\admin\anaconda3\lib\site-packages (from prophet) (1.24.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from prophet) (3.7.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\admin\anaconda3\lib\site-packages (from prophet) (2.0.3)
# Collecting holidays>=0.25 (from prophet)
#   Obtaining dependency information for holidays>=0.25 from https://files.pythonhosted.org/packages/5d/8c/bad7c11afc8969834728c0678bbf8f3ec5dba4c4ac7f5ad8cf91d63e865f/holidays-0.40-py3-none-any.whl.metadata
#   Downloading holidays-0.40-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\admin\anaconda3\lib\site-packages (from prophet) (4.65.0)
# Collecting importlib-resources (from prophet)
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/93/e8/facde510585869b5ec694e8e0363ffe4eba067cb357a8398a55f6a1f8023/importlib_resources-6.1.1-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting stanio~=0.3.0 (from cmdstanpy>=1.0.4->prophet)
#   Obtaining dependency information for stanio~=0.3.0 from https://files.pythonhosted.org/packages/26/01/e2579afa3ad1eade8b54bf5b9e45790d219681b1f8f97edbd2f18c4e1a7d/stanio-0.3.0-py3-none-any.whl.metadata
#   Downloading stanio-0.3.0-py3-none-any.whl.metadata (963 bytes)
# Requirement already satisfied: python-dateutil in c:\users\admin\anaconda3\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Downloading prophet-1.1.5-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/13.3 MB 1.2 MB/s eta 0:00:11
#     --------------------------------------- 0.2/13.3 MB 1.3 MB/s eta 0:00:10
#     --------------------------------------- 0.3/13.3 MB 1.3 MB/s eta 0:00:10
#     --------------------------------------- 0.3/13.3 MB 1.3 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/13.3 MB 1.3 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/13.3 MB 1.3 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/13.3 MB 1.2 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/13.3 MB 1.1 MB/s eta 0:00:12
#    - -------------------------------------- 0.5/13.3 MB 1.1 MB/s eta 0:00:12
#    - -------------------------------------- 0.6/13.3 MB 1.2 MB/s eta 0:00:12
#    -- ------------------------------------- 0.7/13.3 MB 1.2 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/13.3 MB 1.3 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/13.3 MB 1.3 MB/s eta 0:00:10
#    -- ------------------------------------- 0.9/13.3 MB 1.3 MB/s eta 0:00:10
#    -- ------------------------------------- 1.0/13.3 MB 1.3 MB/s eta 0:00:10
#    --- ------------------------------------ 1.1/13.3 MB 1.4 MB/s eta 0:00:09
#    --- ------------------------------------ 1.2/13.3 MB 1.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/13.3 MB 1.5 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.5/13.3 MB 1.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.6/13.3 MB 1.6 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.7/13.3 MB 1.6 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/13.3 MB 1.7 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.0/13.3 MB 1.7 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/13.3 MB 1.7 MB/s eta 0:00:07
#    ------ --------------------------------- 2.3/13.3 MB 1.8 MB/s eta 0:00:07
#    ------- -------------------------------- 2.4/13.3 MB 1.9 MB/s eta 0:00:06
#    ------- -------------------------------- 2.5/13.3 MB 1.9 MB/s eta 0:00:06
#    -------- ------------------------------- 2.7/13.3 MB 1.9 MB/s eta 0:00:06
#    -------- ------------------------------- 2.8/13.3 MB 1.9 MB/s eta 0:00:06
#    --------- ------------------------------ 3.0/13.3 MB 1.9 MB/s eta 0:00:06
#    --------- ------------------------------ 3.1/13.3 MB 1.9 MB/s eta 0:00:06
#    --------- ------------------------------ 3.2/13.3 MB 2.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.4/13.3 MB 2.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.5/13.3 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.6/13.3 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/13.3 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.8/13.3 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.8/13.3 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.9/13.3 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.0/13.3 MB 2.0 MB/s eta 0:00:05
#    ------------ --------------------------- 4.1/13.3 MB 2.0 MB/s eta 0:00:05
#    ------------ --------------------------- 4.2/13.3 MB 2.0 MB/s eta 0:00:05
#    ------------ --------------------------- 4.2/13.3 MB 2.0 MB/s eta 0:00:05
#    ------------ --------------------------- 4.2/13.3 MB 2.0 MB/s eta 0:00:05
#    ------------ --------------------------- 4.3/13.3 MB 1.9 MB/s eta 0:00:05
#    ------------- -------------------------- 4.4/13.3 MB 1.9 MB/s eta 0:00:05
#    ------------- -------------------------- 4.5/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.7/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.8/13.3 MB 1.9 MB/s eta 0:00:05
#    -------------- ------------------------- 4.9/13.3 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 4.9/13.3 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 4.9/13.3 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 5.0/13.3 MB 1.6 MB/s eta 0:00:06
#    -------------- ------------------------- 5.0/13.3 MB 1.6 MB/s eta 0:00:06
#    --------------- ------------------------ 5.0/13.3 MB 1.6 MB/s eta 0:00:06
#    --------------- ------------------------ 5.2/13.3 MB 1.5 MB/s eta 0:00:06
#    --------------- ------------------------ 5.2/13.3 MB 1.5 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.4/13.3 MB 1.6 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.4/13.3 MB 1.6 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.5/13.3 MB 1.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.7/13.3 MB 1.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.8/13.3 MB 1.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.9/13.3 MB 1.6 MB/s eta 0:00:05
#    ------------------ --------------------- 6.0/13.3 MB 1.6 MB/s eta 0:00:05
#    ------------------ --------------------- 6.1/13.3 MB 1.6 MB/s eta 0:00:05
#    ------------------ --------------------- 6.2/13.3 MB 1.6 MB/s eta 0:00:05
#    ------------------- -------------------- 6.4/13.3 MB 1.6 MB/s eta 0:00:05
#    ------------------- -------------------- 6.5/13.3 MB 1.7 MB/s eta 0:00:05
#    ------------------- -------------------- 6.6/13.3 MB 1.6 MB/s eta 0:00:05
#    -------------------- ------------------- 6.7/13.3 MB 1.6 MB/s eta 0:00:05
#    -------------------- ------------------- 6.8/13.3 MB 1.7 MB/s eta 0:00:04
#    -------------------- ------------------- 6.9/13.3 MB 1.7 MB/s eta 0:00:04
#    -------------------- ------------------- 6.9/13.3 MB 1.6 MB/s eta 0:00:04
#    -------------------- ------------------- 7.0/13.3 MB 1.6 MB/s eta 0:00:04
#    --------------------- ------------------ 7.1/13.3 MB 1.6 MB/s eta 0:00:04
#    --------------------- ------------------ 7.1/13.3 MB 1.6 MB/s eta 0:00:04
#    --------------------- ------------------ 7.2/13.3 MB 1.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.4/13.3 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.4/13.3 MB 1.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.5/13.3 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.6/13.3 MB 1.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.6/13.3 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.7/13.3 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.8/13.3 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.9/13.3 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.9/13.3 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.9/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 8.0/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 8.0/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 8.1/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 8.1/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 8.2/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 8.3/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 8.3/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------- -------------- 8.4/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------- -------------- 8.5/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------- -------------- 8.6/13.3 MB 1.6 MB/s eta 0:00:03
#    ------------------------- -------------- 8.7/13.3 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 8.7/13.3 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 8.8/13.3 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 8.9/13.3 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 8.9/13.3 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 9.0/13.3 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 9.1/13.3 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 9.2/13.3 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 9.3/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.4/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.5/13.3 MB 1.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.6/13.3 MB 1.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.6/13.3 MB 1.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.6/13.3 MB 1.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.6/13.3 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.7/13.3 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.8/13.3 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.9/13.3 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.9/13.3 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 10.0/13.3 MB 1.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 10.0/13.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------------ --------- 10.0/13.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------------ --------- 10.1/13.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------------ --------- 10.2/13.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------------ --------- 10.3/13.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------------- -------- 10.4/13.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------------- -------- 10.5/13.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------------- -------- 10.5/13.3 MB 1.4 MB/s eta 0:00:03
#    ------------------------------- -------- 10.6/13.3 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 10.7/13.3 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.7/13.3 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.8/13.3 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.9/13.3 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.9/13.3 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 11.0/13.3 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 11.1/13.3 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 11.2/13.3 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 11.3/13.3 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 11.3/13.3 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.4/13.3 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.4/13.3 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.6/13.3 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.6/13.3 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.7/13.3 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.8/13.3 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.8/13.3 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.9/13.3 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 12.0/13.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 12.0/13.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 12.1/13.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 12.2/13.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 12.2/13.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 12.3/13.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 12.4/13.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 12.5/13.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 12.5/13.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 12.6/13.3 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.7/13.3 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.7/13.3 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.8/13.3 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.9/13.3 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.9/13.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  13.0/13.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  13.0/13.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  13.2/13.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 1.3 MB/s eta 0:00:00
# Downloading cmdstanpy-1.2.0-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.0 kB ? eta -:--:--
#    ---------------------------------------  92.2/93.0 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 93.0/93.0 kB 1.8 MB/s eta 0:00:00
# Downloading holidays-0.40-py3-none-any.whl (889 kB)
#    ---------------------------------------- 0.0/889.6 kB ? eta -:--:--
#    --- ------------------------------------ 71.7/889.6 kB 2.0 MB/s eta 0:00:01
#    ------ --------------------------------- 143.4/889.6 kB 1.7 MB/s eta 0:00:01
#    ------- -------------------------------- 174.1/889.6 kB 1.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 256.0/889.6 kB 1.6 MB/s eta 0:00:01
#    ------------- -------------------------- 307.2/889.6 kB 1.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 389.1/889.6 kB 1.5 MB/s eta 0:00:01
#    -------------------- ------------------- 450.6/889.6 kB 1.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 522.2/889.6 kB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 593.9/889.6 kB 1.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 665.6/889.6 kB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 747.5/889.6 kB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 788.5/889.6 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  870.4/889.6 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 889.6/889.6 kB 1.4 MB/s eta 0:00:00
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading stanio-0.3.0-py3-none-any.whl (6.2 kB)
# Installing collected packages: stanio, importlib-resources, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.0 holidays-0.40 importlib-resources-6.1.1 prophet-1.1.5 stanio-0.3.0

# %%
df=pd.read_csv("annual_data.csv")

# %%
df
# Out:
#        Period                         Inst_sector  Inst_sector_code  \
# 0     2013.06  Non-corporate business enterprises               121
# 1     2013.06  Non-corporate business enterprises               121
# 2     2013.06  Non-corporate business enterprises               121
# 3     2013.06  Non-corporate business enterprises               121
# 4     2013.06  Non-corporate business enterprises               121
# ...       ...                                 ...               ...
# 7291     2015                   Total all sectors               900
# 7292     2015                   Total all sectors               900
# 7293     2015                   Total all sectors               900
# 7294     2015                   Total all sectors               900
# 7295     2015                   Total all sectors               900
#
#                                              Descriptor SNA08TRANS  \
# 0                          Closing balance total assets    LE00000
# 1     Financial assets Closing balance Total financi...    LE00000
# 2     Financial assets Closing balance monetary gold...    LE00000
# 3     Financial assets Closing balance currency and ...    LE00000
# 4      Financial assets Closing balance debt securities    LE00000
# ...                                                 ...        ...
# 7291  Capital Account Closing balances Total non-fin...    LE00000
# 7292  Capital Account Closing balances Produced non-...    LE00000
# 7293  Capital Account Closing balances Non-produced ...    LE00000
# 7294                          Closing balance net worth    LE00000
# 7295    Closing balance total liabilities and net worth    LE00000
#
#      Asset_liability_code
# 0                 A000000
# 1                 AFA0000
# 2                 AFA0100
# 3                 AFA0200
# 4                 AFA0300
# ...                   ...
# 7291              AN00000
# 7292              AN10000
# 7293              AN20000
# 7294              B900000
# 7295              L000000
#
# [7296 rows x 6 columns]

# %%
df['Period']=pd.to_datetime(df['Period'])

# %%
df
# Out:
#          Period                         Inst_sector  Inst_sector_code  \
# 0    2013-06-01  Non-corporate business enterprises               121
# 1    2013-06-01  Non-corporate business enterprises               121
# 2    2013-06-01  Non-corporate business enterprises               121
# 3    2013-06-01  Non-corporate business enterprises               121
# 4    2013-06-01  Non-corporate business enterprises               121
# ...         ...                                 ...               ...
# 7291 2015-01-01                   Total all sectors               900
# 7292 2015-01-01                   Total all sectors               900
# 7293 2015-01-01                   Total all sectors               900
# 7294 2015-01-01                   Total all sectors               900
# 7295 2015-01-01                   Total all sectors               900
#
#                                              Descriptor SNA08TRANS  \
# 0                          Closing balance total assets    LE00000
# 1     Financial assets Closing balance Total financi...    LE00000
# 2     Financial assets Closing balance monetary gold...    LE00000
# 3     Financial assets Closing balance currency and ...    LE00000
# 4      Financial assets Closing balance debt securities    LE00000
# ...                                                 ...        ...
# 7291  Capital Account Closing balances Total non-fin...    LE00000
# 7292  Capital Account Closing balances Produced non-...    LE00000
# 7293  Capital Account Closing balances Non-produced ...    LE00000
# 7294                          Closing balance net worth    LE00000
# 7295    Closing balance total liabilities and net worth    LE00000
#
#      Asset_liability_code
# 0                 A000000
# 1                 AFA0000
# 2                 AFA0100
# 3                 AFA0200
# 4                 AFA0300
# ...                   ...
# 7291              AN00000
# 7292              AN10000
# 7293              AN20000
# 7294              B900000
# 7295              L000000
#
# [7296 rows x 6 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Asset_liability_code']=le.fit_transform(df['Asset_liability_code'])

# %%
df=df.drop('Inst_sector',axis=1)

# %%
df=df.drop('Descriptor',axis=1)

# %%
df=df.drop('SNA08TRANS',axis=1)

# %%
df.plot()
# Out:
# <Axes: >

# %%
data=pd.read_csv("mm8.csv")

# %%
data
# Out:
#        Date               Mine  Equipment    Material  Shift      Operator  \
# 0  1/1/2023  Vasanth Coal Mine    Shovel1  Overburden    Day  Ramesh Patel
# 1  1/1/2023  Vasanth Coal Mine     Truck1        Coal    Day       Aditya
# 2  1/2/2023    Reddy Coal Mine    Shovel1  Overburden  Night   Vijay Kumar
# 3  1/2/2023    Reddy Coal Mine     Truck2        Coal  night  Priya Sharma
# 4  1/5/2023        RP minerals  Dragline1  Overburden    Day    Rahul Jain
# 5  1/5/2023        RP minerals     Truck1        Coal    Day   Ankit Desai
#
#                             Address  Hours_Worked  Target_TPH  Actual TPH
# 0          221B Baker street Mumbai             8        5000        4735
# 1                 50Laxmi nagar hyd             8         800         725
# 2      144 Golf club road Bangalore             8        5000        4210
# 3                   multiline delhi             8         800         855
# 4          G-13 Govt Complex Jaipur            10        7000        6320
# 5  B-302 Solaris Mulund West Mumbai            10         900        1050

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data
# Out:
#         Date               Mine  Equipment    Material  Shift      Operator  \
# 0 2023-01-01  Vasanth Coal Mine    Shovel1  Overburden    Day  Ramesh Patel
# 1 2023-01-01  Vasanth Coal Mine     Truck1        Coal    Day       Aditya
# 2 2023-01-02    Reddy Coal Mine    Shovel1  Overburden  Night   Vijay Kumar
# 3 2023-01-02    Reddy Coal Mine     Truck2        Coal  night  Priya Sharma
# 4 2023-01-05        RP minerals  Dragline1  Overburden    Day    Rahul Jain
# 5 2023-01-05        RP minerals     Truck1        Coal    Day   Ankit Desai
#
#                             Address  Hours_Worked  Target_TPH  Actual TPH
# 0          221B Baker street Mumbai             8        5000        4735
# 1                 50Laxmi nagar hyd             8         800         725
# 2      144 Golf club road Bangalore             8        5000        4210
# 3                   multiline delhi             8         800         855
# 4          G-13 Govt Complex Jaipur            10        7000        6320
# 5  B-302 Solaris Mulund West Mumbai            10         900        1050

# %%
data.set_index('Date',inplace=True)

# %%
data
# Out:
#                          Mine  Equipment    Material  Shift      Operator  \
# Date
# 2023-01-01  Vasanth Coal Mine    Shovel1  Overburden    Day  Ramesh Patel
# 2023-01-01  Vasanth Coal Mine     Truck1        Coal    Day       Aditya
# 2023-01-02    Reddy Coal Mine    Shovel1  Overburden  Night   Vijay Kumar
# 2023-01-02    Reddy Coal Mine     Truck2        Coal  night  Priya Sharma
# 2023-01-05        RP minerals  Dragline1  Overburden    Day    Rahul Jain
# 2023-01-05        RP minerals     Truck1        Coal    Day   Ankit Desai
#
#                                      Address  Hours_Worked  Target_TPH  \
# Date
# 2023-01-01          221B Baker street Mumbai             8        5000
# 2023-01-01                 50Laxmi nagar hyd             8         800
# 2023-01-02      144 Golf club road Bangalore             8        5000
# 2023-01-02                   multiline delhi             8         800
# 2023-01-05          G-13 Govt Complex Jaipur            10        7000
# 2023-01-05  B-302 Solaris Mulund West Mumbai            10         900
#
#             Actual TPH
# Date
# 2023-01-01        4735
# 2023-01-01         725
# 2023-01-02        4210
# 2023-01-02         855
# 2023-01-05        6320
# 2023-01-05        1050

# %%
data=data.drop('Mine',axis=1)

# %%
data=data.drop('Equipment',axis=1)

# %%
data=data.drop('Material',axis=1)

# %%
data=data.drop('Shift',axis=1)

# %%
data=data.drop('Operator',axis=1)

# %%
data=data.drop('Address',axis=1)

# %%
data=data.drop('Hours_Worked',axis=1)

# %%
data=data.drop('Target_TPH',axis=1)

# %%
data
# Out:
#             Actual TPH
# Date
# 2023-01-01        4735
# 2023-01-01         725
# 2023-01-02        4210
# 2023-01-02         855
# 2023-01-05        6320
# 2023-01-05        1050

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(data, order=(0, 1, 1)) 
results_ARIMA = model.fit()

results_ARIMA.summary()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Actual TPH   No. Observations:                    6
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                 -46.353
# Date:                Wed, 10 Jan 2024   AIC                             96.707
# Time:                        11:06:20   BIC                             95.926
# Sample:                             0   HQIC                            94.610
#                                   - 6
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9935      1.079     -0.921      0.357      -3.107       1.120
# sigma2      5.157e+06   2.13e-07   2.42e+13      0.000    5.16e+06    5.16e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.88   Jarque-Bera (JB):                 0.72
# Prob(Q):                              0.03   Prob(JB):                         0.70
# Heteroskedasticity (H):               2.81   Skew:                             0.60
# Prob(H) (two-sided):                  0.52   Kurtosis:                         1.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
# """

# %%
a=results_ARIMA.forecast(3)
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
a
# Out:
# 6    2617.552862
# 7    2617.552862
# 8    2617.552862
# Name: predicted_mean, dtype: float64

# %%
a
data.plot()
plt.show()
