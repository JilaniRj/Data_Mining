# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('annual_data.csv')

# %%
df
# Out:
#        Period                         Inst_sector  Inst_sector_code  \
# 0     2013.06  Non-corporate business enterprises               121
# 1     2013.06  Non-corporate business enterprises               121
# 2     2013.06  Non-corporate business enterprises               121
# 3     2013.06  Non-corporate business enterprises               121
# 4     2013.06  Non-corporate business enterprises               121
# ...       ...                                 ...               ...
# 7291     2015                   Total all sectors               900
# 7292     2015                   Total all sectors               900
# 7293     2015                   Total all sectors               900
# 7294     2015                   Total all sectors               900
# 7295     2015                   Total all sectors               900
#
#                                              Descriptor SNA08TRANS  \
# 0                          Closing balance total assets    LE00000
# 1     Financial assets Closing balance Total financi...    LE00000
# 2     Financial assets Closing balance monetary gold...    LE00000
# 3     Financial assets Closing balance currency and ...    LE00000
# 4      Financial assets Closing balance debt securities    LE00000
# ...                                                 ...        ...
# 7291  Capital Account Closing balances Total non-fin...    LE00000
# 7292  Capital Account Closing balances Produced non-...    LE00000
# 7293  Capital Account Closing balances Non-produced ...    LE00000
# 7294                          Closing balance net worth    LE00000
# 7295    Closing balance total liabilities and net worth    LE00000
#
#      Asset_liability_code
# 0                 A000000
# 1                 AFA0000
# 2                 AFA0100
# 3                 AFA0200
# 4                 AFA0300
# ...                   ...
# 7291              AN00000
# 7292              AN10000
# 7293              AN20000
# 7294              B900000
# 7295              L000000
#
# [7296 rows x 6 columns]

# %%
x=df['Period']
y=df['Asset_liability_code']
plt.bar(x,y)
# Out:
# <BarContainer object of 7296 artists>

# %%
a=df[(df['Asset_liability_code']=='L000000')]

# %%
a
# Out:
#         Period                                 Inst_sector  Inst_sector_code  \
# 23     2014.02          Non-corporate business enterprises               121
# 47    2014. 08              Corporate business enterprises               141
# 71    2014. 08                                Central bank               211
# 95        2015                            Registered banks               221
# 119       2015               Other depository institutions               222
# ...        ...                                         ...               ...
# 7199      2015  Non-profit institutions serving households               400
# 7223      2015                                  Households               511
# 7247      2015                           Rest of the world               611
# 7271      2015      Total economy (excl rest of the world)               800
# 7295      2015                           Total all sectors               900
#
#                                            Descriptor SNA08TRANS  \
# 23    Closing balance total liabilities and net worth    LE00000
# 47    Closing balance total liabilities and net worth    LE00000
# 71    Closing balance total liabilities and net worth    LE00000
# 95    Closing balance total liabilities and net worth    LE00000
# 119   Closing balance total liabilities and net worth    LE00000
# ...                                               ...        ...
# 7199  Closing balance total liabilities and net worth    LE00000
# 7223  Closing balance total liabilities and net worth    LE00000
# 7247  Closing balance total liabilities and net worth    LE00000
# 7271  Closing balance total liabilities and net worth    LE00000
# 7295  Closing balance total liabilities and net worth    LE00000
#
#      Asset_liability_code
# 23                L000000
# 47                L000000
# 71                L000000
# 95                L000000
# 119               L000000
# ...                   ...
# 7199              L000000
# 7223              L000000
# 7247              L000000
# 7271              L000000
# 7295              L000000
#
# [304 rows x 6 columns]

# %%
x=df['Period']
y=df['Inst_sector']
plt.bar(x,y)
# Out:
# <BarContainer object of 7296 artists>

# %%
b=df[(df['Asset_liability_code']=='L000000') & (df['Inst_sector']=='Total all sectors')]

# %%
b
# Out:
#      Period        Inst_sector  Inst_sector_code  \
# 455    2015  Total all sectors               900
# 911    2015  Total all sectors               900
# 1367   2015  Total all sectors               900
# 1823   2015  Total all sectors               900
# 2279   2015  Total all sectors               900
# 2735   2015  Total all sectors               900
# 3191   2015  Total all sectors               900
# 3647   2015  Total all sectors               900
# 4103   2015  Total all sectors               900
# 4559   2015  Total all sectors               900
# 5015   2015  Total all sectors               900
# 5471   2015  Total all sectors               900
# 5927   2015  Total all sectors               900
# 6383   2015  Total all sectors               900
# 6839   2015  Total all sectors               900
# 7295   2015  Total all sectors               900
#
#                                            Descriptor SNA08TRANS  \
# 455   Closing balance total liabilities and net worth    LE00000
# 911   Closing balance total liabilities and net worth    LE00000
# 1367  Closing balance total liabilities and net worth    LE00000
# 1823  Closing balance total liabilities and net worth    LE00000
# 2279  Closing balance total liabilities and net worth    LE00000
# 2735  Closing balance total liabilities and net worth    LE00000
# 3191  Closing balance total liabilities and net worth    LE00000
# 3647  Closing balance total liabilities and net worth    LE00000
# 4103  Closing balance total liabilities and net worth    LE00000
# 4559  Closing balance total liabilities and net worth    LE00000
# 5015  Closing balance total liabilities and net worth    LE00000
# 5471  Closing balance total liabilities and net worth    LE00000
# 5927  Closing balance total liabilities and net worth    LE00000
# 6383  Closing balance total liabilities and net worth    LE00000
# 6839  Closing balance total liabilities and net worth    LE00000
# 7295  Closing balance total liabilities and net worth    LE00000
#
#      Asset_liability_code
# 455               L000000
# 911               L000000
# 1367              L000000
# 1823              L000000
# 2279              L000000
# 2735              L000000
# 3191              L000000
# 3647              L000000
# 4103              L000000
# 4559              L000000
# 5015              L000000
# 5471              L000000
# 5927              L000000
# 6383              L000000
# 6839              L000000
# 7295              L000000
